# %% [raw]
# age=(int(input("Enter your age:")))

# %%
if(age>18):
    print("You can Drive")
elif(age==18):
    print("Get alicense")
elif(age<18):
    print("you cant drive")
else:
    print("Invalid")
# Out:
# you cant drive
